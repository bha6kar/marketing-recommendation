# %%
import pandas as pd
from pandas import DataFrame

user_feature_data: DataFrame = pd.read_feather("data/raw/user_feature_data.feather")
user_feature_data_test: DataFrame = user_feature_data.head(5)
# Save the new DataFrame as a Feather file
user_feature_data_test.to_feather("src/tests/data/user_feature_data.feather")

# %%
user_feature_data_test
# Out:
#                             path_id  n_sessions most_common_landing_page  \
# 0  2ae3158970d6044f06fb0a9b5564cc42           1                      FAQ
# 1  fa6487d637ca997f950dcab63f358c91           2                      FAQ
# 2  b744b3641e1de2f50259314e21fbcdf9           1                      FAQ
# 3  35b3eb0a564f6803202fe12323609d37           5                      FAQ
# 4  a5a3abce4217d87e8b3bb29f6846fee1           1                      FAQ
#
#   clicked_city viewed_city viewed_beach saw_brand saw_organic saw_direct  \
# 0         None        None         None     False       False       True
# 1         None        None         None     False        True       True
# 2         None        None         None     False       False       True
# 3         None        None         None     False        True       True
# 4         None        None         None     False       False       True
#
#    saw_offer_summary  saw_panda  adults  children  nights
# ...

# %%
import pandas as pd

# Sample data
data = {
    "path_id": [
        "2ae3158970d6044f06fb0a9b5564cc42",
        "fa6487d637ca997f950dcab63f358c91",
        "b744b3641e1de2f50259314e21fbcdf9",
        "35b3eb0a564f6803202fe12323609d37",
        "a5a3abce4217d87e8b3bb29f6846fee1",
    ],
    "device_type": [1, 2, 1, 3, 2],
    "attribution_channel": [3, 1, 2, 3, 1],
    "distance_to_last": [10, 5, 8, 12, 15],
    "time_delta_in_days": [7, 3, 5, 8, 6],
    "has_booked": [1, 0, 1, 0, 1],
}

# Create DataFrame
attribution_path_data_test = pd.DataFrame(data)

# Save the new DataFrame as a Feather file
attribution_path_data_test.to_feather("src/tests/data/attribution_path_data.feather")
